# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
extra_train_df = pd.read_csv("C:/Users/Manik/Desktop/fitzpatrick17k.csv")

# %%
extra_train_df['label'].unique()
# Out:
# array(['drug induced pigmentary changes', 'photodermatoses',
#        'dermatofibroma', 'psoriasis', 'kaposi sarcoma',
#        'neutrophilic dermatoses', 'granuloma annulare',
#        'nematode infection', 'allergic contact dermatitis',
#        'necrobiosis lipoidica', 'hidradenitis', 'melanoma',
#        'acne vulgaris', 'sarcoidosis', 'xeroderma pigmentosum',
#        'actinic keratosis', 'scleroderma', 'syringoma', 'folliculitis',
#        'pityriasis lichenoides chronica', 'porphyria',
#        'dyshidrotic eczema', 'seborrheic dermatitis', 'prurigo nodularis',
#        'acne', 'neurofibromatosis', 'eczema', 'pediculosis lids',
#        'basal cell carcinoma', 'pityriasis rubra pilaris',
#        'pityriasis rosea', 'livedo reticularis',
#        'stevens johnson syndrome', 'erythema multiforme',
#        'acrodermatitis enteropathica', 'epidermolysis bullosa',
#        'dermatomyositis', 'urticaria', 'basal cell carcinoma morpheiform',
#        'vitiligo', 'erythema nodosum', 'lupus erythematosus',
#        'lichen planus', 'sun damaged skin', 'drug eruption', 'scabies',
#        'cheilitis', 'urticaria pigmentosa', 'behcets disease',
#        'nevocytic nevus', 'mycosis fungoides',
#        'superficial spreading melanoma ssm', 'porokeratosis of mibelli',
#        'juvenile xanthogranuloma', 'milia', 'granuloma pyogenic',
#        'papilomatosis confluentes and reticulate',
#        'neurotic excoriations', 'epidermal nevus', 'naevus comedonicus',
#        'erythema annulare centrifigum', 'pilar cyst',
#        'pustular psoriasis', 'ichthyosis vulgaris', 'lyme disease',
#        'striae', 'rhinophyma', 'calcinosis cutis', 'stasis edema',
#        'neurodermatitis', 'congenital nevus', 'squamous cell carcinoma',
#        'mucinosis', 'keratosis pilaris', 'keloid', 'tuberous sclerosis',
#        'acquired autoimmune bullous diseaseherpes gestationis',
#        'fixed eruptions', 'lentigo maligna', 'lichen simplex',
#        'dariers disease', 'lymphangioma', 'pilomatricoma',
#        'lupus subacute', 'perioral dermatitis',
#        'disseminated actinic porokeratosis', 'erythema elevatum diutinum',
#        'halo nevus', 'aplasia cutis', 'incontinentia pigmenti',
#        'tick bite', 'fordyce spots', 'telangiectases',
#        'solid cystic basal cell carcinoma', 'paronychia', 'becker nevus',
#        'pyogenic granuloma', 'langerhans cell histiocytosis',
#        'port wine stain', 'malignant melanoma', 'factitial dermatitis',
#        'xanthomas', 'nevus sebaceous of jadassohn',
#        'hailey hailey disease', 'scleromyxedema', 'porokeratosis actinic',
#        'rosacea', 'acanthosis nigricans', 'myiasis',
#        'seborrheic keratosis', 'mucous cyst', 'lichen amyloidosis',
#        'ehlers danlos syndrome', 'tungiasis'], dtype=object)

# %%
# 1) Define your 21 target diseases
desired_diseases = [
    "squamous-cell-carcinoma",
    "basal-cell-carcinoma",
    "folliculitis",
    "acne-vulgaris",
    "melanoma",
    "eczema",
    "acne",
    "mycosis-fungoides",
    "actinic-keratosis",
    "prurigo-nodularis",
    "kaposi-sarcoma",
    "keloid",
    "dermatomyositis",
    "superficial-spreading-melanoma-ssm",
    "pyogenic-granuloma",
    "malignant-melanoma",
    "epidermal-nevus",
    "dyshidrotic-eczema",
    "dermatofibroma",
    "seborrheic-keratosis",
    "basal-cell-carcinoma-morpheiform"
]

# 2) Filter the DataFrame
train_df_filtered = extra_train_df[extra_train_df['label'].isin(desired_diseases)]

# 3) Check the distribution to confirm only the 21 diseases remain
print(train_df_filtered['label'].value_counts())

# 4) (Optional) Overwrite the old DataFrame or save to new CSV
extra_train_df.to_csv("filtered_train.csv", index=False)
# train_df.to_csv("filtered_train.csv", index=False)  # If you want a CSV output
# Out:
# label
# folliculitis       342
# melanoma           261
# eczema             204
# acne               183
# keloid             156
# dermatomyositis    151
# dermatofibroma      79
# Name: count, dtype: int64

# %%
print(extra_train_df.columns)
# Out:
# Index(['md5hash', 'fitzpatrick_scale', 'fitzpatrick_centaur', 'label',
#        'nine_partition_label', 'three_partition_label', 'qc', 'url',
#        'url_alphanum'],
#       dtype='object')

# %%
print(extra_train_df['label'].unique())
# Out:
# ['drug induced pigmentary changes' 'photodermatoses' 'dermatofibroma'
#  'psoriasis' 'kaposi sarcoma' 'neutrophilic dermatoses'
#  'granuloma annulare' 'nematode infection' 'allergic contact dermatitis'
#  'necrobiosis lipoidica' 'hidradenitis' 'melanoma' 'acne vulgaris'
#  'sarcoidosis' 'xeroderma pigmentosum' 'actinic keratosis' 'scleroderma'
#  'syringoma' 'folliculitis' 'pityriasis lichenoides chronica' 'porphyria'
#  'dyshidrotic eczema' 'seborrheic dermatitis' 'prurigo nodularis' 'acne'
#  'neurofibromatosis' 'eczema' 'pediculosis lids' 'basal cell carcinoma'
#  'pityriasis rubra pilaris' 'pityriasis rosea' 'livedo reticularis'
#  'stevens johnson syndrome' 'erythema multiforme'
#  'acrodermatitis enteropathica' 'epidermolysis bullosa' 'dermatomyositis'
#  'urticaria' 'basal cell carcinoma morpheiform' 'vitiligo'
#  'erythema nodosum' 'lupus erythematosus' 'lichen planus'
#  'sun damaged skin' 'drug eruption' 'scabies' 'cheilitis'
#  'urticaria pigmentosa' 'behcets disease' 'nevocytic nevus'
#  'mycosis fungoides' 'superficial spreading melanoma ssm'
#  'porokeratosis of mibelli' 'juvenile xanthogranuloma' 'milia'
#  'granuloma pyogenic' 'papilomatosis confluentes and reticulate'
#  'neurotic excoriations' 'epidermal nevus' 'naevus comedonicus'
#  'erythema annulare centrifigum' 'pilar cyst' 'pustular psoriasis'
#  'ichthyosis vulgaris' 'lyme disease' 'striae' 'rhinophyma'
#  'calcinosis cutis' 'stasis edema' 'neurodermatitis' 'congenital nevus'
#  'squamous cell carcinoma' 'mucinosis' 'keratosis pilaris' 'keloid'
#  'tuberous sclerosis'
#  'acquired autoimmune bullous diseaseherpes gestationis' 'fixed eruptions'
#  'lentigo maligna' 'lichen simplex' 'dariers disease' 'lymphangioma'
#  'pilomatricoma' 'lupus subacute' 'perioral dermatitis'
#  'disseminated actinic porokeratosis' 'erythema elevatum diutinum'
#  'halo nevus' 'aplasia cutis' 'incontinentia pigmenti' 'tick bite'
#  'fordyce spots' 'telangiectases' 'solid cystic basal cell carcinoma'
#  'paronychia' 'becker nevus' 'pyogenic granuloma'
#  'langerhans cell histiocytosis' 'port wine stain' 'malignant melanoma'
#  'factitial dermatitis' 'xanthomas' 'nevus sebaceous of jadassohn'
#  'hailey hailey disease' 'scleromyxedema' 'porokeratosis actinic'
#  'rosacea' 'acanthosis nigricans' 'myiasis' 'seborrheic keratosis'
#  'mucous cyst' 'lichen amyloidosis' 'ehlers danlos syndrome' 'tungiasis']

# %%
# Our 21 diseases are:
desired_diseases = [
    "squamous-cell-carcinoma",
    "basal-cell-carcinoma",
    "folliculitis",
    "acne-vulgaris",
    "melanoma",
    "eczema",
    "acne",
    "mycosis-fungoides",
    "actinic-keratosis",
    "prurigo-nodularis",
    "kaposi-sarcoma",
    "keloid",
    "dermatomyositis",
    "superficial-spreading-melanoma-ssm",
    "pyogenic-granuloma",
    "malignant-melanoma",
    "epidermal-nevus",
    "dyshidrotic-eczema",
    "dermatofibroma",
    "seborrheic-keratosis",
    "basal-cell-carcinoma-morpheiform"
]

# Defining label mapping dictionary 
label_mapping = {
    "squamous cell carcinoma": "squamous-cell-carcinoma",
    "basal cell carcinoma": "basal-cell-carcinoma",
    "folliculitis": "folliculitis",
    'acne vulgaris': 'acne-vulgaris',
    "melanoma": "melanoma",
    "eczema": "eczema",
    "acne": "acne",
    "mycosis fungoides":"mycosis-fungoides",
    "actinic keratosis ":"actinic-keratosis ",
    "prurigo nodularis" : "prurigo-nodularis",
    "kaposi sarcoma":"kaposi-sarcoma",
    "keloid":"keloid",
    "dermatomyositis":"dermatomyositis",
    "superficial spreading melanoma ssm": "superficial-spreading-melanoma-ssm",
    "pyogenic granuloma":"pyogenic-granuloma",
    "malignant melanoma": "malignant-melanoma",
    "epidermal nevus": "epidermal-nevus",
    "dyshidrotic eczema": "dyshidrotic-eczema",
    "dermatofibroma": "dermatofibroma",
    "seborrheic keratosis": "seborrheic-keratosis",
    "basal cell carcinoma morpheiform": "basal-cell-carcinoma-morpheiform"
}

# 1) Replace the raw labels with normalized ones
extra_train_df['label'] = extra_train_df['label'].replace(label_mapping)

# 2) Filter to keep only the 21 diseases we want
filtered_df = extra_train_df[extra_train_df['label'].isin(desired_diseases)]

print(filtered_df['label'].value_counts())
print(filtered_df.shape)
# Out:
# label
# squamous-cell-carcinoma               581
# basal-cell-carcinoma                  468
# folliculitis                          342
# acne-vulgaris                         335
# melanoma                              261
# eczema                                204
# acne                                  183
# mycosis-fungoides                     182
# prurigo-nodularis                     170
# kaposi-sarcoma                        156
# keloid                                156
# dermatomyositis                       151
# superficial-spreading-melanoma-ssm    118
# pyogenic-granuloma                    113
# malignant-melanoma                    111
# epidermal-nevus                        91
# dyshidrotic-eczema                     83
# dermatofibroma                         79
# seborrheic-keratosis                   69
# basal-cell-carcinoma-morpheiform       62
# Name: count, dtype: int64
# (3915, 9)

# %%
# filtered_df.to_csv("filtered_train.csv", index=False)  # If you want a CSV output

# %%
import csv
import requests

# Define the base path for the extended dataset
base_path = 'C:/Users/Manik/Desktop/BTT Project/BTAI-AJL-Team-2/bttai-ajl-2025/extended_dataset'

# Define headers to mimic a browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8"
}

csv_path = "C:/Users/Manik/Desktop/BTT Project/BTAI-AJL-Team-2/bttai-ajl-2025/filtered_train.csv"

# Open the CSV file and process each row
with open(csv_path, mode='r', encoding='utf-8') as dataset:
    file = csv.reader(dataset)
    headers_row = next(file)  # Skip the header row

    for line in file:
        img_name = line[0]  # md5hash as the image name
        category = line[3]  # label as the category (e.g., "acne", "melanoma")
        img_url = line[7]   # URL of the image

        if not img_url:
            print(f"Skipping {img_name}, empty URL")
            continue

        print(f"Downloading: {img_name} from {img_url}")

        try:
            response = requests.get(img_url, headers=headers, timeout=10)
            if response.status_code == 200:
                # Create the subfolder for the category
                subfolder = os.path.join(base_path, category)
                os.makedirs(subfolder, exist_ok=True)

                # Define the save path within the category subfolder
                save_path = os.path.join(subfolder, f"{img_name}.jpeg")
                with open(save_path, 'wb') as f:
                    f.write(response.content)
            else:
                print(f"Failed to download {img_url}, Status code: {response.status_code}")
        except Exception as e:
            print(f"ERROR: GET request for {img_url} failed with exception {e}")
# Out:
# Downloading: d2bac3c9e4499032ca8e9b07c7d3bc40 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma71.jpg
# Downloading: 45f7fe0e10214e32e890cad9d29d4811 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma4.jpg
# Downloading: b87804452f60aa162a6d29c0f66a2466 from https://www.dermaamin.com/site/images/clinical-pic/L/lmm/lmm6.jpg
# Downloading: d1fb87ee7ee50f997cd6497dd90d6bbb from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris150.jpg
# Downloading: 4c3f795cf8eb72b946f9bd2642cf23c1 from https://www.dermaamin.com/site/images/clinical-pic/m/melanoma/melanoma17.jpg
# Downloading: 99247c9fe486aa9ab71686c8e676c135 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma13.jpg
# Downloading: f968e591e15f47b544e551bc3cc5b8d3 from https://www.dermaamin.com/site/images/clinical-pic/f/folliculitis/folliculitis89.jpg
# Downloading: cd38c6d449b05025a1e68bd94d387f47 from https://www.dermaamin.com/site/images/clinical-pic/h/hidrotic_ectodermal_dysplasia/hidrotic_ectodermal_dysplasia4.jpg
# Downloading: 9d5a90fa3f6934608add10e698001760 from https://www.dermaamin.com/site/images/clinical-pic/p/prurigo_nodularis/prurigo_nodularis27.jpg
# Downloading: 4235913d0b8803702095b54856a07702 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_aggravated_by_steroids/acne_aggravated_by_steroids7.jpg
# Downloading: 31749f92677e70999c28fe49fbc6dafc from https://www.dermaamin.com/site/images/clinical-pic/e/eczema/eczema99.jpg
# Downloading: d2c77aa81ca884f99174471132bd3e24 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma/basal_cell_carcinoma33.jpg
# Downloading: 5f4376e41dff7efbbb53ca5b9928919d from https://www.dermaamin.com/site/images/clinical-pic/p/prurigo_nodularis/prurigo_nodularis97.jpg
# Downloading: 3ebdf5bc47b0a5db96b1cb22841b0fa0 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis89.jpg
# Downloading: 6d2fb27bbaf2691ea85fa2ad7f334060 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma_morpheiform/basal_cell_carcinoma_morpheiform6.jpg
# Downloading: 67ac5bbaeb3f15071e74a36f64270aef from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma57.jpg
# Downloading: dab1abcb214f3e1cf7b509fa75972eb7 from https://www.dermaamin.com/site/images/clinical-pic/m/mycosis-fongoide/mycosis-fongoide99.jpg
# Downloading: 81c007db8cc1bc57cb08bcc00dda653b from https://www.dermaamin.com/site/images/clinical-pic/s/superfacial-spreading-melanoma/superfacial-spreading-melanoma112.jpg
# Downloading: d98b961ecb24b31d672ca92d42fa644f from https://www.dermaamin.com/site/images/clinical-pic/e/epidermal_naevus/epidermal_naevus53.jpg
# Downloading: 39b1853bbd7aee8beb2bd4be5bf0f922 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis97.jpg
# Downloading: 53d69b9f140ac6b48514141564dc6b2f from https://www.dermaamin.com/site/images/clinical-pic/e/eczema/eczema48.jpg
# Downloading: 9838b6548e7842a1c228e9548a32099c from https://www.dermaamin.com/site/images/clinical-pic/c/carcinoma_basal_cell/carcinoma_basal_cell10.jpg
# Downloading: 1616459eaaa8f79463b01fd100f419bf from https://www.dermaamin.com/site/images/clinical-pic/p/pseudofolliculitis-barbae/pseudofolliculitis-barbae24.jpg
# Downloading: a7821ca7a0f65f9095a61d66c234f683 from https://www.dermaamin.com/site/images/clinical-pic/g/gorlin_syndrome/gorlin_syndrome3.jpg
# Downloading: 9d5e4780260cf2955e3e0e783cb21247 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma58.jpg
# Downloading: 862d0d4096cacb124d4e0df53c32b0e0 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_comedonal/acne_comedonal7.jpg
# Downloading: 204f57f5c4dd76c0841f106da6993d53 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris7.jpg
# Downloading: 0d4c5e2266a00cd127cd5a676ac872b5 from https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma94.jpg
# Downloading: 72714f4963e82e6d9b7b4f99a4f3b32e from https://www.dermaamin.com/site/images/clinical-pic/e/eczema_atopic/eczema_atopic38.jpg
# Downloading: f83855461747896f3735a1263f4e6d1e from https://www.dermaamin.com/site/images/clinical-pic/c/cheloide/cheloide9.jpg
# Downloading: c3833afba496feeb4153ed76ff2da85d from https://www.dermaamin.com/site/images/clinical-pic/c/carcinome_basocellulaire_nodulaire/carcinome_basocellulaire_nodulaire7.jpg
# Downloading: 58e7594f5727cdfc362cf5b071520a1f from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma84.jpg
# Downloading: 44bb284877cbebaeb393b2ed07606de5 from https://www.dermaamin.com/site/images/clinical-pic/h/hot_tub_folliculitis/hot_tub_folliculitis8.jpg
# Downloading: 08447c464a1134284f6e267a3dffdf6f from https://www.dermaamin.com/site/images/clinical-pic/e/eczema_atopic/eczema_atopic31.jpg
# Downloading: 23ca2b5bdef55b891b276df1c82e9be2 from https://www.dermaamin.com/site/images/clinical-pic/c/cheloide/cheloide6.jpg
# Downloading: a42224fcf640f0bca5a7564b9792495a from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma101.jpg
# Downloading: c189dc271fd1ac6dd7c389e43129368e from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid47.jpg
# Downloading: 5de18144953b0dcf774605ae4a9c65c3 from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma93.jpg
# Downloading: c18ef5d1ddaa5651b201046f079f1607 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma33.jpg
# Downloading: 1920c507d09dd56dee4e4d423efefc9b from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris333.jpg
# Downloading: 213877be1a20cbc68975c1e43644f1d9 from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid115.jpg
# Downloading: 1bbe4519608f606a18adf1811fd1c051 from https://www.dermaamin.com/site/images/clinical-pic/c/carcinoma_basal_cell/carcinoma_basal_cell3.jpg
# Downloading: 43d7ea1cae8cfa3f6a9f7ac73e7d1479 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma_morpheiform/basal_cell_carcinoma_morpheiform48.jpg
# Downloading: 568062107b882079931f07d874639343 from https://www.dermaamin.com/site/images/clinical-pic/d/dracunculiasis/dracunculiasis2.jpg
# Downloading: 521bec867654c32d592f32f9256c5704 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinomas_cystic/basal_cell_carcinomas_cystic13.jpg
# Downloading: ae895d961f33a66f43003eea737dc42f from https://www.dermaamin.com/site/images/clinical-pic/a/acne_scarring/acne_scarring13.jpg
# Downloading: 07360bff59d68a64fe7e279625a4bbd4 from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma26.jpg
# Downloading: fc00af3afd475aa7679fe83be88b4b8e from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma2.jpg
# Downloading: c60d8659cd66191da36c8a7151716af2 from https://www.dermaamin.com/site/images/clinical-pic/a/anhidrotic_ectodermal_dysplasia/anhidrotic_ectodermal_dysplasia1.jpg
# Downloading: d95bb36bbdb0f6f3224029ef6afc14e1 from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid40.jpg
# Downloading: 3d9887b1f426ac5a3a3ed5e2b8c56b87 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis163.jpg
# Downloading: 2c74321d5e74fddb13c2d77b64cbe9b2 from https://www.dermaamin.com/site/images/clinical-pic/m/mycosis-fongoide/mycosis-fongoide12.jpg
# Downloading: f08034a69a57680dbe4521f6e913ba22 from https://www.dermaamin.com/site/images/clinical-pic/c/carcinome_basocellulaire_nodulaire/carcinome_basocellulaire_nodulaire10.jpg
# Downloading: 945c7b1a4ae963372eb00a3919ef9b5d from https://www.dermaamin.com/site/images/clinical-pic/n/neonatal-acne/neonatal-acne2.jpg
# Downloading: acd8feb1ca7fddf6e5237aa3eaced966 from https://www.dermaamin.com/site/images/clinical-pic/p/pyogenic-granuloma/pyogenic-granuloma19.jpg
# Downloading: bb6e7390c63e78607a7308076972713a from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-melanoma/malignant-melanoma82.jpg
# Downloading: 86942c44aa1bf357cc2e8861d02a0c30 from https://www.dermaamin.com/site/images/clinical-pic/p/pityrosporum-folliculitis/pityrosporum-folliculitis5.jpg
# Downloading: 1869b3068ba7dc3abd802d435a4bac96 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris271.jpg
# Downloading: 1b0f82951e82535fa4f79a16802490d2 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma9.jpg
# Downloading: 2004c88f0aba56122257c4f71e67c719 from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-melanoma/malignant-melanoma1.jpg
# Downloading: cb399ec010d1031fbaa1dad093a3a328 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma21.jpg
# Downloading: e4b2d2e8706fc69f39d8d2bafeff9cf9 from https://www.dermaamin.com/site/images/clinical-pic/e/eczema_hand/eczema_hand11.jpg
# Downloading: 54f09a0af80b1930a3210d57df1f373e from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma11.jpg
# Downloading: 0ec3ad42fa779284c90cf3eafd31a6e7 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis124.jpg
# Downloading: c0d87b8dc5b8419b85c8fa07517007fd from https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma52.jpg
# Downloading: 1579e85ffbc506c10a9c44e58f23227e from https://www.dermaamin.com/site/images/clinical-pic/e/eczema/eczema110.jpg
# Downloading: 3c51c4031263c4fabc496dc1bcad04ff from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid15.jpg
# Downloading: bb2e052ba0951cf787b9e831ab2a5b10 from https://www.dermaamin.com/site/images/clinical-pic/s/superfacial-spreading-melanoma/superfacial-spreading-melanoma68.jpg
# Downloading: 6cba1a3c302571165ea1d3f81f0ddf5b from https://www.dermaamin.com/site/images/clinical-pic/e/eczema/eczema77.jpg
# Downloading: 951559d1b2d52080c2bd4323a7bf58bf from https://www.dermaamin.com/site/images/clinical-pic/p/pseudofolliculitis-barbae/pseudofolliculitis-barbae21.jpg
# Downloading: 69cfcc29d1376d77c9bcbfca301eefb6 from https://www.dermaamin.com/site/images/clinical-pic/c/carcinome_spinocellulaire/carcinome_spinocellulaire4.jpg
# Downloading: 9a2685b99d2db77c7297891d1c5b2dae from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma60.jpg
# Downloading: fb41d70e2f3ac0f981d4d2eb6f199318 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma64.jpg
# Downloading: 22f13657c4a6b4a3fc6ea06d313c3725 from https://www.dermaamin.com/site/images/clinical-pic/m/melanome-superficiel-extensif/melanome-superficiel-extensif17.jpg
# Downloading: 4ff4109275ef98c7cd754dee47249adc from https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma82.jpg
# Downloading: becab807bbe933d1a5e84f378dfc083f from https://www.dermaamin.com/site/images/clinical-pic/s/superfacial-spreading-melanoma/superfacial-spreading-melanoma33.jpg
# Downloading: 42bb46cb779b95f10e531e2b6181e439 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma/basal_cell_carcinoma85.jpg
# Downloading: 993841d17697a0ff4c5e60a9c307e483 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis175.jpg
# Skipping 480fd80167d7865ce9aafe14aba4ec9d, empty URL
# Downloading: 4fb3b473a70b32545595f49757d68755 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris259.jpg
# Downloading: 61666c0ec14deb9728144948debffd74 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris48.jpg
# Downloading: 8f023e0be7de1b39bf539ac80f9a3389 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris158.jpg
# Downloading: 407d41dc4b0e9e0fddd2fe5a4e155986 from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-melanoma/malignant-melanoma49.jpg
# Downloading: 6fcaf3c1ecef5a938bf70ae2b6ed24f6 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinomas_cystic/basal_cell_carcinomas_cystic43.jpg
# Downloading: 7a973c126993a6366636eae00fe17335 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris236.jpg
# Downloading: c686ea44d704970a3a5c8ac99f7fcb3e from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid83.jpg
# Downloading: 75f3059a6ad92bc7ef724a4ac79dc492 from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma34.jpg
# Downloading: 3791b30f96733f69b473c8d2fcf3998b from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-melanoma/malignant-melanoma13.jpg
# Downloading: 77aa716ae6d1b7c52f7007fd36864dc2 from https://www.dermaamin.com/site/images/clinical-pic/s/superfacial-spreading-melanoma/superfacial-spreading-melanoma114.jpg
# Downloading: a3cb5d0e0904a32c4a0cf3049104fda3 from https://www.dermaamin.com/site/images/clinical-pic/n/neonatal-acne/neonatal-acne3.jpg
# Downloading: 64637b40830089f8776bbf5cc2ac2251 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris79.jpg
# Downloading: 297ee70fefe78b688233154f8befb1e3 from https://www.dermaamin.com/site/images/clinical-pic/m/mycosis-fongoide/mycosis-fongoide20.jpg
# Downloading: 0f94533e693dab70850adb978cc0d821 from https://www.dermaamin.com/site/images/clinical-pic/p/prurigo_nodularis/prurigo_nodularis67.jpg
# Downloading: 6fd7ab66c3fae6ec708d373480a78068 from https://www.dermaamin.com/site/images/clinical-pic/p/pseudofolliculitis-barbae/pseudofolliculitis-barbae15.jpg
# Downloading: 961d7614dcde8fe49ca6bd24e0d05ed1 from https://www.dermaamin.com/site/images/clinical-pic/e/eczema_atopic/eczema_atopic33.jpg
# Downloading: 99282ae41e691d80fe46124d0efdbe53 from https://www.dermaamin.com/site/images/clinical-pic/p/pompholyx/pompholyx26.jpg
# Downloading: 57b5a38f58b25a43d4997a599154baf9 from https://www.dermaamin.com/site/images/clinical-pic/k/keratoacanthoma/keratoacanthoma49.jpg
# Downloading: 1850974b8167c043208c99b90b126cf0 from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid95.jpg
# Downloading: 8f11fe151cb9ede441d591dbfc171948 from https://www.dermaamin.com/site/images/clinical-pic/b/bowens_disease/bowens_disease18.jpg
# Downloading: d80eb8dcd60ddbbadecd602d7e3234be from https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma69.jpg
# Downloading: cf3d2262e2ddccfee4641197f689e6dd from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma/basal_cell_carcinoma84.jpg
# Downloading: d04150a06562fb2c21073a745b42f7dc from https://www.dermaamin.com/site/images/clinical-pic/p/pompholyx/pompholyx38.jpg
# Downloading: b26064c02eae1fac1547c843c9e48624 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatomyositis/dermatomyositis118.jpg
# Downloading: c26cfe58bbd48bbdc2542d2a0fe3fbf0 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris57.jpg
# Downloading: 90fee053dd8d3d2fea0fbf8b569fc6f1 from https://www.dermaamin.com/site/images/clinical-pic/n/neonatal-acne/neonatal-acne7.jpg
# Downloading: b580a075146386af3e2cfb6c8b026a40 from https://www.dermaamin.com/site/images/clinical-pic/m/mycosis-fongoide/mycosis-fongoide78.jpg
# Downloading: 545f0e8a6125523973e200172976448a from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma99.jpg
# Downloading: 0eea95f33aa97fec0d44afde061d5595 from https://www.dermaamin.com/site/images/clinical-pic/e/erythroplasia_of_queyrat/erythroplasia_of_queyrat14.jpg
# Downloading: 1681c65312e7c67fcec67b39a5f31162 from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-melanoma/malignant-melanoma74.jpg
# Downloading: 38d20f98356a171a3c206985213c366b from https://www.dermaamin.com/site/images/clinical-pic/s/squamous-cell-carcinoma/squamous-cell-carcinoma92.jpg
# Downloading: dbe818063c1b16bd569d8c89c304018d from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris231.jpg
# Downloading: fa874a1a22d0ac96cd101b8c492ce962 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_rosacae/acne_rosacae19.jpg
# Downloading: 7ba9fd85c64320e2137448742a5abfa4 from https://www.dermaamin.com/site/images/clinical-pic/e/eczema_cracquele/eczema_cracquele14.jpg
# Downloading: a4280c9e0cd2206daf06d3ab32bc4a51 from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid63.jpg
# Downloading: e170d124649f3cddf0e8d2ac7a4e597f from https://www.dermaamin.com/site/images/clinical-pic/m/melanoma/melanoma20.jpg
# Downloading: 72e2febe065d177b01564edeb420e24b from https://www.dermaamin.com/site/images/clinical-pic/m/melanoma/melanoma45.jpg
# Downloading: 84d8616020e202285cb4b5505d18541b from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinomas_cystic/basal_cell_carcinomas_cystic24.jpg
# Downloading: 16e8de6bd449154d0823adddef933b73 from https://www.dermaamin.com/site/images/clinical-pic/m/malignant-lymphoma/malignant-lymphoma7.jpg
# Downloading: 322b68d37074c1950a21243137800788 from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma32.jpg
# Downloading: 3c421aa1b1d94df229df3c6ae9a4530a from https://www.dermaamin.com/site/images/clinical-pic/s/seborrheic-keratoses/seborrheic-keratoses15.jpg
# Downloading: e59fa554a20a472017c6870e671566e0 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris104.jpg
# Downloading: 4ac07b83e993297cb8ef4efa00212fce from https://www.dermaamin.com/site/images/clinical-pic/a/acne_comedonal/acne_comedonal15.jpg
# Downloading: 29864b78ce1ecb22e47e6794e6c7d4f8 from https://www.dermaamin.com/site/images/clinical-pic/p/pompholyx/pompholyx19.jpg
# Downloading: 6eefcee64440fb29088135a15a4c9348 from https://www.dermaamin.com/site/images/clinical-pic/b/bowens_disease/bowens_disease57.jpg
# Downloading: 83cd9569896510c012ebc6c5bb7f3c74 from https://www.dermaamin.com/site/images/clinical-pic/a/acro_lentiginous_melanoma/acro_lentiginous_melanoma10.jpg
# Downloading: 25a9a37f1edef70afe4cbfb380f01224 from https://www.dermaamin.com/site/images/clinical-pic/m/melanoma/melanoma38.jpg
# Downloading: 1f39c3d1c78eb459d4b7d44ac850733e from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid10.jpg
# Downloading: 69ff175300cf6db570894f58aff1a957 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_comedonal/acne_comedonal9.jpg
# Downloading: 2475581bf40d111f31146165fce3441b from https://www.dermaamin.com/site/images/clinical-pic/p/pyogenic-granuloma/pyogenic-granuloma59.jpg
# Downloading: a0107ef5c6fae2196d575795e561371c from https://www.dermaamin.com/site/images/clinical-pic/h/hidrotic_ectodermal_dysplasia/hidrotic_ectodermal_dysplasia6.jpg
# Downloading: a92bc582cd740326cd53e39f2941b3dd from https://www.dermaamin.com/site/images/clinical-pic/k/kekoid/kekoid114.jpg
# Downloading: fa57573afd04db4c44dd3ec5465964cc from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris314.jpg
# Downloading: 37776f44e7f4949826d0fd29525620d4 from https://www.dermaamin.com/site/images/clinical-pic/b/bowens_disease/bowens_disease8.jpg
# Downloading: a9ec397cb5c5fd7006ad8fd4e58579f8 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris190.jpg
# Downloading: 4776fafd70c95bad8d8d465817f97c72 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_scarring/acne_scarring17.jpg
# Downloading: 1b30b27a7fdd32f127605d702e29792b from https://www.dermaamin.com/site/images/clinical-pic/a/acne_scarring/acne_scarring24.jpg
# Downloading: e7fd792efe793efba7a339d3dd29e404 from https://www.dermaamin.com/site/images/clinical-pic/s/superfacial-spreading-melanoma/superfacial-spreading-melanoma56.jpg
# Downloading: 7a93256d43142337dbdec318b2ab4096 from https://www.dermaamin.com/site/images/clinical-pic/f/folliculitis/folliculitis9.jpg
# Downloading: 0d582dfe778f718b94bd58195433eb47 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma_morpheiform/basal_cell_carcinoma_morpheiform38.jpg
# Downloading: adb5b7253c21d274f9b1a793b01b84d2 from https://www.dermaamin.com/site/images/clinical-pic/e/erythroplasia_of_queyrat/erythroplasia_of_queyrat27.jpg
# Downloading: 648adc09de37624a92674d2b90d96188 from https://www.dermaamin.com/site/images/clinical-pic/k/kaposis-sarcoma/kaposis-sarcoma47.jpg
# Downloading: a523aefe8b934e7389f3086ffc7f07f3 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris206.jpg
# Downloading: cc63958a1cedccb7dc1f0628f010206e from https://www.dermaamin.com/site/images/clinical-pic/m/melanoma/melanoma29.jpg
# Downloading: dd458e1b9a1f498d87991da0e95800b0 from https://www.dermaamin.com/site/images/clinical-pic/a/acne_scarring/acne_scarring11.jpg
# Downloading: f7397e523494dd9243c2c795b1e0525f from https://www.dermaamin.com/site/images/clinical-pic/a/acne_vulgaris/acne_vulgaris171.jpg
# Downloading: e654f6c8ac970fe75d7fd45967f5c27a from https://www.dermaamin.com/site/images/clinical-pic/d/dermatofibroma/dermatofibroma54.jpg
# Downloading: 576c5c37a21c1c767733e486ac69b71c from https://www.dermaamin.com/site/images/clinical-pic/L/lmm/lmm1.jpg
# Downloading: a49abcfad0d9a5270d1c9488a6fc466f from https://www.dermaamin.com/site/images/clinical-pic/e/eruptive_xanthoma/eruptive_xanthoma1.jpg
# Downloading: 763bec8f103de2ce2d39da5cea02c5f7 from https://www.dermaamin.com/site/images/clinical-pic/e/eczema/eczema29.jpg
# Downloading: 11bee91943e3e14af9a21326fc13ad64 from https://www.dermaamin.com/site/images/clinical-pic/e/eosinophilic_pustula_folliculitis/eosinophilic_pustula_folliculitis25.jpg
# Downloading: d2e96d346577a155b0125dda66b16395 from https://www.dermaamin.com/site/images/clinical-pic/b/basal_cell_carcinoma/basal_cell_carcinoma36.jpg
